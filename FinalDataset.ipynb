# %%
import pandas as pd

# %%
df1=pd.read_csv('bot1.csv')
df2 = pd.read_csv('human.csv')

# %%
df1
# Out:
#                                                  content
# 0      Media will never show you this!  Looking forwa...
# 1      Rewind of East Iberville stopping 46-game losi...
# 2                     Beautiful. https://t.co/CYEUZsqdqT
# 3                   THATS BAE �� https://t.co/LQFmbhbEOH
# 4      Taxpayers foot hefty bill of presidential sear...
# ...                                                  ...
# 75715  #BlackTwitter: WE ARE LIVING IT, WE ARE LOVING...
# 75716  What you need to know to register to vote in K...
# 75717  #NowPlaying: Jurassic 5 "Customer Service" #hi...
# 75718  Philly special needs student dies after fighti...
# 75719  Full Show: With All Due Respect (10/14/16)  #p...
#
# [75720 rows x 1 columns]

# %%
df2
# Out:
#                                                 content
# 0     Leaked records show Trump may have avoided tax...
# 1     Donald Trump vs. Hillary Clinton Debate Cold O...
# 2     @realDonaldTrump The need is to blow off the "...
# 3     US-Medien: Trump zahlte womÃ¶glich jahrelang k...
# 4     #amjoy #cnn #msnbc #Trump has 2 words for #dep...
# ...                                                 ...
# 7693  Since 1986-2016(30Years) =20Years Republican A...
# 7694  Onlooker repeatedly yells â€˜Bill Clinton is a...
# 7695  I'm having a very hard time right now in sever...
# 7696  Between #trump, Giuliani, Ailes they have 10 d...
# 7697  Larry David brings Bernie Sanders back to â€˜S...
#
# [7698 rows x 1 columns]

# %%
df1['Labels']=1
df2['Labels']=0

# %%
df1
# Out:
#                                                  content  Labels
# 0      Media will never show you this!  Looking forwa...       1
# 1      Rewind of East Iberville stopping 46-game losi...       1
# 2                     Beautiful. https://t.co/CYEUZsqdqT       1
# 3                   THATS BAE �� https://t.co/LQFmbhbEOH       1
# 4      Taxpayers foot hefty bill of presidential sear...       1
# ...                                                  ...     ...
# 75715  #BlackTwitter: WE ARE LIVING IT, WE ARE LOVING...       1
# 75716  What you need to know to register to vote in K...       1
# 75717  #NowPlaying: Jurassic 5 "Customer Service" #hi...       1
# 75718  Philly special needs student dies after fighti...       1
# 75719  Full Show: With All Due Respect (10/14/16)  #p...       1
#
# [75720 rows x 2 columns]

# %%
df2
# Out:
#                                                 content  Labels
# 0     Leaked records show Trump may have avoided tax...       0
# 1     Donald Trump vs. Hillary Clinton Debate Cold O...       0
# 2     @realDonaldTrump The need is to blow off the "...       0
# 3     US-Medien: Trump zahlte womÃ¶glich jahrelang k...       0
# 4     #amjoy #cnn #msnbc #Trump has 2 words for #dep...       0
# ...                                                 ...     ...
# 7693  Since 1986-2016(30Years) =20Years Republican A...       0
# 7694  Onlooker repeatedly yells â€˜Bill Clinton is a...       0
# 7695  I'm having a very hard time right now in sever...       0
# 7696  Between #trump, Giuliani, Ailes they have 10 d...       0
# 7697  Larry David brings Bernie Sanders back to â€˜S...       0
#
# [7698 rows x 2 columns]

# %%
df=pd.concat([df1, df2]) 
dfs=df.sample(frac=1)

# %%
dfs.tail(50)
# Out:
#                                                  content  Labels
# 1495                    #LostIn3Words  I'm heart broken.       1
# 9631   "#IHaveARightToKnow why mom is this late comin...       1
# 58026  Sculptor BMGs "Crush Nazism" is unveiled in #O...       1
# 67139  #NowPlaying: "6 O'Clock Briefing" by Billy Dan...       1
# 6942                           @MikeRumbo66 @claydirtman       0
# 33150  Yes - shaming isn't working either. I cringe e...       1
# 43484            *burns African American Studies degree*       1
# 7277   Stressed out by U.S. election? Tune out and as...       0
# 48046  Hey Hillary, What Kind of Genius Loses $6 Bill...       1
# 7011   Turkey arrests some 32,000 in coup plot invest...       1
# 61136  #BetterAlternativeToDebates A Blaxploitation m...       1
# 54871  Foke FBI 'will not prosecute Brad Pitt over al...       1
# 41865  This goes back to the short comings of the pol...       1
# ...

# %%
#dfs.to_csv('bot_or_human.csv')
