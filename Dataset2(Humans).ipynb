# %%
import pandas as pd
df = pd.read_fwf('human.txt',header=None)
df['content'] = df

# %%
df.drop([0],axis=1,inplace=True)

# %%
df
# Out:
#                                                 content
# 0     Leaked records show Trump may have avoided tax...
# 1     Donald Trump vs. Hillary Clinton Debate Cold O...
# 2     @realDonaldTrump The need is to blow off the "...
# 3     US-Medien: Trump zahlte womÃ¶glich jahrelang k...
# 4     #amjoy #cnn #msnbc #Trump has 2 words for #dep...
# 5     and you people who can't  good old boy loans a...
# 6     How Hostile Poll-Watchers Could Hand Pennsylva...
# 7     Watch Alec Baldwin as Donald Trump on SNLâ€™s ...
# 8     Eric Trump Thinks Bill Clinton Is â€˜The Worst...
# 9     #itweetFEEDS Leaked records show Trump may hav...
# 10    So Trump losing $916 mil is supposed to make u...
# 11    Trump Tax Records Obtained by The Times Reveal...
# 12    Trump Tax Records Obtained by The Times Reveal...
# 13    Alec Baldwin Slays With Hilarious Donald Trump...
# 14     Watch it &amp; weep ðŸ˜‚ https://t.co/Bjd7xoKf27
# 15    hilarious, ya gotta watch!! ............ Donal...
# ...

# %%
df.to_csv('human.csv')
